# %% [markdown]
# **Mohamed Rafiq M**
#
# Task 1 - Optical Character Recognition

# %% [markdown]
# Installing then necessary dependencies

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.6/dist-packages (0.3.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (7.0.0)

# %% [markdown]
# Importing the necessary libraries

# %%
from PIL import Image
import pytesseract
import os
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# Defining a function to extract **text** from **image** using **pytesseract**

# %%
def ocr(image):
  img = Image.open(image)
  image_read = cv2.imread(image)
  cv2_imshow(image_read)
  text = pytesseract.image_to_string(img, lang='eng')
  print(text)

# %%
ocr('img1.png')
# Out:
# <PIL.Image.Image image mode=RGB size=699x204 at 0x7FA4D95B2208>
# So I called Poison Control - quite calmly I might add - and explained what happened.
# (This is the 3rd time this year I've had to call Poison Control with Emily.) The woman was
# very nice (I really do appreciate that, it makes all the difference) and upon calculating
# Emily's weight and figuring how much actual fluoride was in the amount, determined that
# even if Emily drank the full 2-3 0z, she had not ingested a toxic amount. Thank God!
# While on the phone, I discovered a kitchen towel soaked in the mouthwash, so we safely
# concluded that Emily was perfectly fine. It didn’t make sense to me that she would drink
# more than a sip anyways as it’s a rather strong mouthwash (nothing like Listerine, but
# still it has an edge to it) and I wouldn’t think it would be appealing to a 2 year old. At the
# recommendation of the poison control lady, I gave Emily some extra milk to drink as that
# is supposed to bind with the fluoride and help further, but there’s nothing to worry about.

# %%
ocr('img2.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=279x185 at 0x7FA4D95C4F98>
# The studio was filled with the rich
# odor of roses, and when the light
# summer wind stirred amidst the
# trees of the garden there came
# through the open door the heavy
# scent of the lilac, or the more
# delicate perfume of the pink-
#
# flowering thorn.

# %%
ocr('img3.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=512x400 at 0x7FA4D95C4F28>
# Hi Rob,
#
# We wanted to take « quick momen?
# jost to say Fhanit you, Your haed
# work today truly has made This 4
# Special day, not only for 05, bot
# also ter ovr tamil avd Friends,
# com the bottom or ove hearts,
#
# Thank you! buat r Stacy

# %%
ocr('img4.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=2218x623 at 0x7FA4D95D8080>
# As historians Study the Revolutionary Wor, it has become
# dpiivus Ynot ne colonists were divided into Sore distinct Groups
# ‘based on their opinion of the wor. In the articles “Riricts,
# Loyohiats ond Neuirolists ” ond “Aiktudes “Towards the Revolut
# Now,” Ye leliefs of Ynese Wnree Qroups are exolained.
